# %%
# predicted as a batch
from parameters import par
from model import DeepVO
import numpy as np
from PIL import Image
import os
import time
import torch

from data_helper import get_data_info, ImageSequenceDataset
from torch.utils.data import DataLoader
from helper import eulerAnglesToRotationMatrix
from sthree_wrapper import to_s3_npy, read_img, list_contents, test_read, load_npy

# %%
list_contents('{}{}/image_2/'.format(par.sequence_key, test_video))
# Out:
# [{'Key': 'sequences/00/image_2/000000.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 19, tzinfo=tzlocal()),
#   'ETag': '"8c81916da1a3b960335e9215f8ef5f8b"',
#   'Size': 851565,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000001.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 18, tzinfo=tzlocal()),
#   'ETag': '"5c3ae10c4f97c37976ecd1ac52e4c2ba"',
#   'Size': 838481,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000002.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 19, tzinfo=tzlocal()),
#   'ETag': '"19a2c950fb8868baa57d71adeae5191c"',
#   'Size': 840684,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000003.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 19, tzinfo=tzlocal()),
#   'ETag': '"1cacb6438b23f6b66807b57a933cc6af"',
#   'Size': 844349,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000004.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 19, tzinfo=tzlocal()),
#   'ETag': '"badc9731c67f06b90ac7f2de89326dd7"',
#   'Size': 850438,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000005.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 19, tzinfo=tzlocal()),
#   'ETag': '"5ac629e82aa3ae0508636e80d9f8080a"',
#   'Size': 850223,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000006.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 19, tzinfo=tzlocal()),
#   'ETag': '"1d7d60e6c6d25fe094f732815e2fc166"',
#   'Size': 848681,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000007.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 19, tzinfo=tzlocal()),
#   'ETag': '"1b63f1afcb7192c680c97e29c4fe2a99"',
#   'Size': 852604,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000008.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 19, tzinfo=tzlocal()),
#   'ETag': '"18ab7637a35aa56c72e14b9bdf70e4be"',
#   'Size': 855653,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000009.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 19, tzinfo=tzlocal()),
#   'ETag': '"54c9bbd22d51896ddfd736f7cc10ba20"',
#   'Size': 851698,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000010.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 20, tzinfo=tzlocal()),
#   'ETag': '"e72c8dcf0f3c9eb7c91aaa41810b5332"',
#   'Size': 842779,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000011.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 20, tzinfo=tzlocal()),
#   'ETag': '"a8379740ca4d6bacb9af5691ace6bcfb"',
#   'Size': 836011,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000012.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 21, tzinfo=tzlocal()),
#   'ETag': '"12fc29cc197ab6644d704b036fa7f20f"',
#   'Size': 823677,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000013.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 21, tzinfo=tzlocal()),
#   'ETag': '"d2877af01e11e713f180c6c3bcb16ba6"',
#   'Size': 815844,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000014.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 21, tzinfo=tzlocal()),
#   'ETag': '"e04450e318195b945b0e828d4153afba"',
#   'Size': 792771,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000015.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 22, tzinfo=tzlocal()),
#   'ETag': '"b20d721948540c74c4accea9aaf30c5f"',
#   'Size': 775237,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000016.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 22, tzinfo=tzlocal()),
#   'ETag': '"a55acc4592c5ab4bca5aef3f4044d577"',
#   'Size': 772735,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000017.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 22, tzinfo=tzlocal()),
#   'ETag': '"9a33bc1659ade36832dac5286d878e99"',
#   'Size': 781113,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000018.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 22, tzinfo=tzlocal()),
#   'ETag': '"1471e22715a699da64eb3fc0c228df87"',
#   'Size': 793650,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000019.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 22, tzinfo=tzlocal()),
#   'ETag': '"a4d2bb0b58df1d7d86da7f059966316e"',
#   'Size': 816483,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000020.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 23, tzinfo=tzlocal()),
#   'ETag': '"465c01843693e37e339a3ecc354a66fe"',
#   'Size': 830335,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000021.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 23, tzinfo=tzlocal()),
#   'ETag': '"ea2c87c55a00144d1bc5a67d33b93858"',
#   'Size': 840379,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000022.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 23, tzinfo=tzlocal()),
#   'ETag': '"df6248862e5ab4ea1528a3b8b59d4b13"',
#   'Size': 846860,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000023.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 47, 23, tzinfo=tzlocal()),
#   'ETag': '"a703693bf5c9eac0e625c10cffd662ef"',
#   'Size': 843017,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/

#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000963.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 28, tzinfo=tzlocal()),
#   'ETag': '"7eda0a78f74d7b406b429db6b2b2fafe"',
#   'Size': 896214,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000964.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 29, tzinfo=tzlocal()),
#   'ETag': '"348a875d2adf37c234a4db0d0e13c26b"',
#   'Size': 903027,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000965.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 29, tzinfo=tzlocal()),
#   'ETag': '"ff518202805221109c508b5db3dd6598"',
#   'Size': 908178,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000966.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 29, tzinfo=tzlocal()),
#   'ETag': '"b3b3ccdf1f0d55459fb867ba686bd858"',
#   'Size': 905948,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000967.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 30, tzinfo=tzlocal()),
#   'ETag': '"ed9f3d465ebde1991891ce4427b1bdff"',
#   'Size': 890605,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000968.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 30, tzinfo=tzlocal()),
#   'ETag': '"cb82c523cb745bfad0f224233770ffaf"',
#   'Size': 888683,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000969.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 30, tzinfo=tzlocal()),
#   'ETag': '"b6f40c23e9e96ca7223e3bc57eaa7423"',
#   'Size': 873105,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000970.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 30, tzinfo=tzlocal()),
#   'ETag': '"9e0d4e9e2363c160b5af3c25e96c503c"',
#   'Size': 866215,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000971.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 30, tzinfo=tzlocal()),
#   'ETag': '"f0cdd6020e939d21456d5148757c45a6"',
#   'Size': 864454,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000972.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 31, tzinfo=tzlocal()),
#   'ETag': '"8d0f46bffd939895d841f345bf48e162"',
#   'Size': 866717,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000973.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 31, tzinfo=tzlocal()),
#   'ETag': '"f18e75abc8b2e50e84977f3069a7f33a"',
#   'Size': 867814,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000974.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 32, tzinfo=tzlocal()),
#   'ETag': '"d3fe380b56fd25688308f5fe842cc6d9"',
#   'Size': 868890,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000975.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 32, tzinfo=tzlocal()),
#   'ETag': '"a80f33439146f948ac64da1d53dfca35"',
#   'Size': 849710,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000976.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 33, tzinfo=tzlocal()),
#   'ETag': '"ee0e5f1862db1a9c0b60ecb7021d6453"',
#   'Size': 840367,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000977.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 33, tzinfo=tzlocal()),
#   'ETag': '"a7084fdf4825559566f298b7e182d01b"',
#   'Size': 847708,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000978.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 33, tzinfo=tzlocal()),
#   'ETag': '"d1c87d8dc4aeb3f2e92045a3dc7094de"',
#   'Size': 851002,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000979.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 33, tzinfo=tzlocal()),
#   'ETag': '"1a20b6f610f0937ae34885d64384efc6"',
#   'Size': 862677,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000980.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 33, tzinfo=tzlocal()),
#   'ETag': '"7bccfe7ece8db8aa80072c8b5adb38b3"',
#   'Size': 868401,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000981.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 33, tzinfo=tzlocal()),
#   'ETag': '"70d0937fe2c988a7a906f6b76aeba25b"',
#   'Size': 872478,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000982.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 34, tzinfo=tzlocal()),
#   'ETag': '"82ec9b6c9062e55fc7b27b9e75cdfbef"',
#   'Size': 885260,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000983.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 34, tzinfo=tzlocal()),
#   'ETag': '"cba68b08bdd23549cf782eea162c6e04"',
#   'Size': 886521,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000984.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 35, tzinfo=tzlocal()),
#   'ETag': '"3a3fc898c6f1eb92d4e4d567f7f4712c"',
#   'Size': 877340,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000985.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 35, tzinfo=tzlocal()),
#   'ETag': '"fa423c38ee98294e99f9f9eee1225792"',
#   'Size': 865769,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000986.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 35, tzinfo=tzlocal()),
#   'ETag': '"694bbb99d849180770856a05fbff7a8a"',
#   'Size': 860923,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000987.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 36, tzinfo=tzlocal()),
#   'ETag': '"6ad82790dce6126be7da4fea348fc996"',
#   'Size': 859306,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000988.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 36, tzinfo=tzlocal()),
#   'ETag': '"8c97fe0403d2db481549f1f357eaf733"',
#   'Size': 853207,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000989.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 36, tzinfo=tzlocal()),
#   'ETag': '"14630df7de8bd52103ddf4d8df5111cc"',
#   'Size': 846249,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000990.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 36, tzinfo=tzlocal()),
#   'ETag': '"bff70b84a3e0db0688e37b94c355d935"',
#   'Size': 833974,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000991.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 36, tzinfo=tzlocal()),
#   'ETag': '"60e4845182016617c7c12afda4e96911"',
#   'Size': 849575,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000992.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 37, tzinfo=tzlocal()),
#   'ETag': '"b3869b6c1aa1ebb9f624af3f82229089"',
#   'Size': 831147,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000993.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 37, tzinfo=tzlocal()),
#   'ETag': '"73844673e5934251a4058991cb68f1d2"',
#   'Size': 828547,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000994.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 38, tzinfo=tzlocal()),
#   'ETag': '"e85f30bcbd6e8c82e1bafb46ccd1bd05"',
#   'Size': 845611,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000995.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 38, tzinfo=tzlocal()),
#   'ETag': '"153d112db55319517b6aeb256693157d"',
#   'Size': 850161,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000996.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 38, tzinfo=tzlocal()),
#   'ETag': '"ba0216c1baf25f9d360a5264debc8088"',
#   'Size': 856828,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000997.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 38, tzinfo=tzlocal()),
#   'ETag': '"1cb752e51c2cd4eb3e742b9d417a5e38"',
#   'Size': 865192,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000998.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 39, tzinfo=tzlocal()),
#   'ETag': '"406134c0210d2a2e6c3b9a0ac14062c4"',
#   'Size': 876555,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}},
#  {'Key': 'sequences/00/image_2/000999.png',
#   'LastModified': datetime.datetime(2022, 1, 4, 4, 51, 39, tzinfo=tzlocal()),
#   'ETag': '"aff20a7d7ec576006332ae3e9caba7c2"',
#   'Size': 892397,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'deepankerk',
#    'ID': '1e4f2619b2912ddd926600d3246d586939a15102e0a529bc76af64e5adbf9af6'}}]

# %%
videos_to_test = ['00']

# Path
load_model_path = "models/t000104_v04_im184x608_s5x10_b8_rnn1000_optAdagrad_lr0.0005.model.train"   #choose the model you want to load
save_dir = 'result/'  # directory to save prediction answer
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Load model
M_deepvo = DeepVO(par.img_h, par.img_w, par.batch_norm)
use_cuda = torch.cuda.is_available()
if use_cuda:
    M_deepvo = M_deepvo.cuda()
    M_deepvo.load_state_dict(torch.load("models/model-1500000.meta")) # Replace with load_model_path
    print("loaded model")
    #M_deepvo.load_state_dict(torch.load(load_model_path))
else:
    M_deepvo.load_state_dict(torch.load(load_model_path, map_location={'cuda:0': 'cpu'}))
print('Load model from: ', load_model_path)

# Data
n_workers = 1
seq_len = int((par.seq_len[0]+par.seq_len[1])/2)
overlap = seq_len - 1
print('seq_len = {},  overlap = {}'.format(seq_len, overlap))
batch_size = par.batch_size

fd=open('test_dump.txt', 'w')
fd.write('\n'+'='*50 + '\n')

for test_video in videos_to_test:
    df = get_data_info(folder_list=[test_video], seq_len_range=[seq_len, seq_len], overlap=overlap, sample_times=1, shuffle=False, sort=False)
    df = df.loc[df.seq_len == seq_len]  # drop last
    dataset = ImageSequenceDataset(df, par.resize_mode, (par.img_w, par.img_h), par.img_means, par.img_stds, par.minus_point_5)
    df.to_csv('test_df.csv')
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=n_workers)
    
    #print('{}{}.npy'.format(par.pose_location, test_video))
    gt_pose = load_npy('{}{}.npy'.format(par.pose_location, test_video))  # (n_images, 6)
    #print(gt_pose)
    
    # Predict
    M_deepvo.eval()
    has_predict = False
    answer = [[0.0]*6, ]
    st_t = time.time()
    n_batch = len(dataloader)

    for i, batch in enumerate(dataloader):
        print('{} / {}'.format(i, n_batch), end='\r', flush=True)
        _, x, y = batch
        if use_cuda:
            x = x.cuda()
            y = y.cuda()
        batch_predict_pose = M_deepvo.forward(x)

        # Record answer
        fd.write('Batch: {}\n'.format(i))
        for seq, predict_pose_seq in enumerate(batch_predict_pose):
            for pose_idx, pose in enumerate(predict_pose_seq):
                fd.write(' {} {} {}\n'.format(seq, pose_idx, pose))
        
        batch_predict_pose = batch_predict_pose.data.cpu().numpy()
        if i == 0:
            for pose in batch_predict_pose[0]:
                # use all predicted pose in the first prediction
                for i in range(len(pose)):
                    # Convert predicted relative pose to absolute pose by adding last pose
                    pose[i] += answer[-1][i]
                answer.append(pose.tolist())
            batch_predict_pose = batch_predict_pose[1:]

        # transform from relative to absolute 
        for predict_pose_seq in batch_predict_pose:
            # predict_pose_seq[1:] = predict_pose_seq[1:] + predict_pose_seq[0:-1]
            ang = eulerAnglesToRotationMatrix([0, answer[-1][0], 0]) #eulerAnglesToRotationMatrix([answer[-1][1], answer[-1][0], answer[-1][2]])
            location = ang.dot(predict_pose_seq[-1][3:])
            predict_pose_seq[-1][3:] = location[:]

        # use only last predicted pose in the following prediction
            last_pose = predict_pose_seq[-1]
            for i in range(len(last_pose)):
                last_pose[i] += answer[-1][i]
            # normalize angle to -Pi...Pi over y axis
            last_pose[0] = (last_pose[0] + np.pi) % (2 * np.pi) - np.pi
            answer.append(last_pose.tolist())

    print('len(answer): ', len(answer))
    print('expect len: ', len(list_contents('{}{}/image_2/'.format(par.sequence_key, test_video))))
    print('Predict use {} sec'.format(time.time() - st_t))
    
    # Save answer
    with open('{}/out_{}.txt'.format(save_dir, test_video), 'w') as f:
        for pose in answer:
            if type(pose) == list:
                f.write(', '.join([str(p) for p in pose]))
            else:
                f.write(str(pose))
            f.write('\n')
    
    # Calculate loss
    gt_pose = load_npy('{}{}.npy'.format(par.pose_location, test_video))  # (n_images, 6)
    loss = 0
    for t in range(len(answer)):
        angle_loss = np.sum((answer[t][:3] - gt_pose[t,:3]) ** 2)
        translation_loss = np.sum((answer[t][3:] - gt_pose[t,3:6]) ** 2)
        loss = (100 * angle_loss + translation_loss)
    loss /= len(gt_pose)
    print('Loss = ', loss)
    print('='*50)
print("DONE")
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-6-478ff8ddd310> in <module>
#      12 if use_cuda:
#      13     M_deepvo = M_deepvo.cuda()
# ---> 14     M_deepvo.load_state_dict(torch.load("models/model-1500000.meta")) # Replace with load_model_path
#      15     print("loaded model")
#      16     #M_deepvo.load_state_dict(torch.load(load_model_path))
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     606                     return torch.jit.load(opened_file)
#     607                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
# --> 608         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     609
#     610
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/torch/serialization.py in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#     775             "functionality.")
#     776
# --> 777     magic_number = pickle_module.load(f, **pickle_load_args)
#     778     if magic_number != MAGIC_NUMBER:
#     779         raise RuntimeError("Invalid magic number; corrupt file?")
#
# UnpicklingError: invalid load key, '\x0a'.
